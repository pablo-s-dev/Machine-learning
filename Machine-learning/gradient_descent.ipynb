# %% [markdown]
# <a href="https://colab.research.google.com/github/pablo-s-dev/Machine-learning/blob/main/Machine-learning/gradient_descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation
from sklearn.linear_model import LinearRegression
import time
# %matplotlib inline

# %%
fig = plt.subplots()
ax, = plt.axis()

# %%
x_train = np.random.random_sample(100)
y_train = 2* x_train + (np.random.random_sample(100) - np.random.random_sample(100)) / 1.5

plt.scatter(x_train, y_train)


def gradient_descent(x_train, y_train, w = 0, b = 0, lrate = 0.1):

  def DJDb(w, b):
    e = 1e-6
    step = 0.001

    y_hat = lambda x: w * x + b
    new_y_hat = lambda x: w * x + (b + step)

    delta_j = calc_error(new_y_hat, y_train, x_train) - calc_error(y_hat, y_train, x_train)

    if(abs(delta_j) < e):
      return 0

    return delta_j / step

  def DJDw(w, b):
    step = 1e-6
    e = 1e-10

    y_hat = lambda x: w * x + b
    new_y_hat = lambda x: (w + step) * x + b

    delta_j: float = calc_error(new_y_hat, y_train, x_train) - calc_error(y_hat, y_train, x_train)
    print(delta_j)
    if(abs(delta_j) < e ):
      return 0

    return delta_j / step

  i = 0

  while (i < 1e6):

    plt.plot(x_train, b + x_train * w)

    plt.pause(0.001)

    new_w = w - lrate * DJDw(w, b)
    new_b = b - lrate * DJDb(w, b)

    if( new_w == w and new_b == b):

      return lambda x: w * x + b

    w = new_w
    b = new_b



    i += 1

  return lambda x: w * x + b



def calc_error(y_hat, y, x) -> float:
  m = len(y_train)

  squared_sum = 0
  for i in range(m):
    squared_sum += (y_hat(x[i]) - y[i]) ** 2

  return squared_sum / m





y_hat = gradient_descent(x_train, y_train)

# model = LinearRegression()
# model.fit(x_train.reshape((-1, 1)), y_train)
# plt.plot(x_train, model.intercept_ + model.coef_ * (x_train))


def animate(t):
  fig
# Out:
# -1.3156371678757495e-06
# -1.0270311833204815e-06
# -8.113204414961217e-07
# -6.499476227217471e-07
# -5.290815615066613e-07
# -4.3841357200147257e-07
# -3.702603288413542e-07
# -3.188952292232372e-07
# -2.800500481237034e-07
# -2.5054351290854093e-07
# -2.2800447549431446e-07
# -2.106655878630903e-07
# -1.972095226288051e-07
# -1.866543642981e-07
# -1.7826818332622452e-07
# -1.7150537212629047e-07
# -1.659591908620417e-07
# -1.6132640315302815e-07
# -1.5738091449502e-07
# -1.53954128556677e-07
# -1.5092030328234252e-07
# -1.4818563728868916e-07
# -1.4568013745330788e-07
# -1.4335155526512544e-07
# -1.41160869215895e-07
# -1.3907891679987294e-07
# -1.3708388504896085e-07
# -1.3515943905750838e-07
# -1.3329332865241739e-07
# -1.314763480864123e-07
# -1.2970156290648127e-07
# -1.2796373100032454e-07
# -1.2625887388373336e-07
# -1.2458395487469076e-07
# -1.2293664067297705e-07
# -1.2131512303059644e-07
# ---------------------------------------------------------------------------
# ...
